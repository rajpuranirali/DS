# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# create a line plot
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x,y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Basic line Plot')
# Out:
# Text(0.5, 1.0, 'Basic line Plot')

# %%
# customized a line plot 
x = [1,2,3,4,5,9]
y = [1,4,8,10,26,25]
plt.plot(x,y, color='red', linestyle =  '--', marker='o',linewidth =3 ,markersize = '9') #marker = '*'
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Basic line Plot')
plt.grid(True)

# %%
# Multiple plots
x = [1,2,3,4,5]
y1 = [1,4,9,16,25]
y2= [1,2,3,4,5]
plt.figure(figsize = (9,5))

plt.subplot(1,2,1) #(1:rows, 2:columns, 1:plot)
plt.plot(x,y1,color = 'green')
plt.title('Plot 1',color = 'blue')
# plt.xlabel('X axis',color = 'blue')
# plt.ylabel('Y axis',color = 'blue')

plt.subplot(1,2,2) #(1:rows, 2:columns, 2:plot)
plt.plot(y1,x,color = 'red')
plt.title('Plot 1',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Plot 1')

# %%
# Multiple plots
x = [1,2,3,4,5]
y1 = [1,4,9,16,25]
y2= [1,2,3,4,5]
plt.figure(figsize = (9,5))

plt.subplot(2,2,1) #(2:rows,2:columns,1:plot)
plt.plot(x,y1,color = 'green')
plt.title('Plot 1',color = 'blue')
# plt.xlabel('X axis',color = 'blue')
# plt.ylabel('Y axis',color = 'blue')

plt.subplot(2,2,2) #(1:rows, 2:columns, 2:plot)
plt.plot(y1,x,color = 'red')
plt.title('Plot 2',color = 'blue')

plt.subplot(2,2,3) #(2:rows, 2:columns, 3:plot)
plt.plot(y1,x,color = 'yellow')
plt.title('Plot 3',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Plot 3')

# %%
# Multiple plots
x = [1,2,3,4,5]
y1 = [1,4,9,16,25]
y2= [1,2,3,4,5]
plt.figure(figsize = (9,5))

plt.subplot(2,2,1) #(2:rows,2:columns,1:plot)
plt.plot(x,y1,color = 'green')
plt.title('Plot 1',color = 'blue')
# plt.xlabel('X axis',color = 'blue')
# plt.ylabel('Y axis',color = 'blue')

plt.subplot(2,2,2) #(1:rows, 2:columns, 2:plot)
plt.plot(y1,x,color = 'red')
plt.title('Plot 2',color = 'blue')

plt.subplot(2,2,3) #(2:rows, 2:columns, 3:plot)
plt.plot(y1,x,color = 'yellow')
plt.title('Plot 3',color = 'blue')


plt.subplot(2,2,4) #(2:rows, 2:columns, 3:plot)
plt.plot(y1,x,color = 'pink')
plt.title('Plot 4',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Plot 4')

# %%
# bar plot
